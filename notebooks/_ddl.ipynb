# %%
#schema
spark.sql("create schema if not exists workspace.football_project")

#volume
spark.sql("create volume if not exists workspace.football_project.raw_data")
spark.sql("create volume if not exists workspace.football_project.docs")

# %%
# spark.sql("DROP volume IF exists football_project.matches")
# spark.sql("DROP VOLUME IF EXISTS football_project.three_sixty")
# spark.sql("DROP volume IF exists football_project.events")
# spark.sql("DROP volume IF exists football_project.lineups")
